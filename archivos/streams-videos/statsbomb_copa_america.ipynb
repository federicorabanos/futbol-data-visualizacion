# %%
from statsbombpy import sb
import pandas as pd

# %%
sb.competitions().competition_name.value_counts()
# Out:
# c:\Users\Federico Rábanos\AppData\Local\Programs\Python\Python310\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# competition_name
# Champions League           18
# La Liga                    18
# FIFA World Cup              8
# Ligue 1                     3
# Copa del Rey                3
# FA Women's Super League     3
# 1. Bundesliga               2
# UEFA Euro                   2
# Serie A                     2
# Premier League              2
# Liga Profesional            2
# Women's World Cup           2
# African Cup of Nations      1
# Major League Soccer         1
# North American League       1
# NWSL                        1
# Indian Super league         1
# FIFA U20 World Cup          1
# Copa America                1
# UEFA Europa League          1
# UEFA Women's Euro           1
# Name: count, dtype: int64

# %%
sb.competitions().head()
# Out:
# c:\Users\Federico Rábanos\AppData\Local\Programs\Python\Python310\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#    competition_id  season_id country_name        competition_name  \
# 0               9        281      Germany           1. Bundesliga
# 1               9         27      Germany           1. Bundesliga
# 2            1267        107       Africa  African Cup of Nations
# 3              16          4       Europe        Champions League
# 4              16          1       Europe        Champions League
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                       True
# 3               male              False                      False
# ...

# %%
competitions = sb.competitions()
# Out:
# c:\Users\Federico Rábanos\AppData\Local\Programs\Python\Python310\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
competitions[competitions['match_available_360'].isna() != True]
# Out:
#     competition_id  season_id              country_name     competition_name  \
# 0                9        281                   Germany        1. Bundesliga
# 29              43        106             International       FIFA World Cup
# 38              11         90                     Spain              La Liga
# 58               7        235                    France              Ligue 1
# 59               7        108                    France              Ligue 1
# 61              44        107  United States of America  Major League Soccer
# 68              55        282                    Europe            UEFA Euro
# 69              55         43                    Europe            UEFA Euro
# 71              53        106                    Europe    UEFA Women's Euro
# 72              72        107             International    Women's World Cup
#
#    competition_gender  competition_youth  competition_international  \
# ...

# %%
competitions[competitions['competition_name'] == 'Copa America']
# Out:
#     competition_id  season_id   country_name competition_name  \
# 21             223        282  South America     Copa America
#
#    competition_gender  competition_youth  competition_international  \
# 21               male              False                       True
#
#    season_name               match_updated match_updated_360  \
# 21        2024  2024-07-15T18:00:33.653673              None
#
#    match_available_360             match_available
# 21                None  2024-07-15T18:00:33.653673

# %%
sb.matches(competition_id=223, season_id=282)
# Out:
# c:\Users\Federico Rábanos\AppData\Local\Programs\Python\Python310\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     match_id  match_date      kick_off                   competition season  \
# 0    3943077  2024-07-15  04:15:00.000  South America - Copa America   2024
# 1    3943076  2024-07-14  03:00:00.000  South America - Copa America   2024
# 2    3942852  2024-07-11  03:00:00.000  South America - Copa America   2024
# 3    3942785  2024-07-10  03:00:00.000  South America - Copa America   2024
# 4    3942416  2024-07-07  01:00:00.000  South America - Copa America   2024
# 5    3942415  2024-07-07  04:00:00.000  South America - Copa America   2024
# 6    3939986  2024-06-30  03:00:00.000  South America - Copa America   2024
# 7    3939973  2024-06-24  04:00:00.000  South America - Copa America   2024
# 8    3942229  2024-07-06  04:00:00.000  South America - Copa America   2024
# ...

# %%
final = sb.events(match_id=3943077, split=True, flatten_attrs=False)
# Out:
# c:\Users\Federico Rábanos\AppData\Local\Programs\Python\Python310\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
final
# Out:
# defaultdict(list,
#             {'starting_xis':                                      id  index  period     timestamp  minute  \
#              0  279b7d66-92b5-4daa-8ff6-cba8fce271d9      1       1  00:00:00.000       0
#              1  06195288-8ea1-489f-9496-3060ac479c36      2       1  00:00:00.000       0
#
#                 second         type  possession possession_team  play_pattern       team  \
#              0       0  Starting XI           1       Argentina  Regular Play  Argentina
#              1       0  Starting XI           1       Argentina  Regular Play   Colombia
#
#                 duration                                            tactics  match_id  \
#              0       0.0  {'formation': 442, 'lineup': [{'player': {'id'...   3943077
#              1       0.0  {'formation': 41212, 'lineup': [{'player': {'i...   3943077
#
#                 possession_team_id  team_id
#              0                 779      779
# ...

# %%
final.keys()
# Out:
# dict_keys(['starting_xis', 'half_starts', 'passes', 'ball_receipts', 'carrys', 'pressures', 'shots', 'goal_keepers', 'clearances', 'blocks', 'dribbled_pasts', 'dribbles', 'duels', 'ball_recoverys', 'miscontrols', 'interceptions', 'foul_committeds', 'foul_wons', 'dispossesseds', 'tactical_shifts', 'injury_stoppages', 'offsides', 'player_offs', 'player_ons', 'shields', 'half_ends', '50/50s', 'referee_ball_drops', 'substitutions', 'bad_behaviours'])

# %%
from mplsoccer import Pitch
import matplotlib.pyplot as plt

# %%
recepciones = final['ball_receipts']
coordenadas = recepciones[recepciones['player'] == 'Rodrigo Javier De Paul'].location.apply(pd.Series).rename(columns={0:'x', 1:'y'})

fig, ax = plt.subplots()

pitch = Pitch(pitch_type='statsbomb')
pitch.draw(ax=ax)
pitch.scatter(coordenadas.x, coordenadas.y,ax=ax)

# %%
final['dribbles'].groupby('player').count()['id']
# Out:
# player
# Alexis Mac Allister                1
# Davinson Sánchez Mina              1
# Gonzalo Ariel Montiel              1
# James David Rodríguez Rubio        2
# Jhon Adolfo Arias Andrade          1
# Johan Andrés Mojica Palacio        2
# Juan Fernando Quintero Paniagua    4
# Julián Álvarez                     1
# Kevin Duvan Castaño Gil            1
# Lautaro Javier Martínez            1
# Lionel Andrés Messi Cuccittini     1
# Luis Fernando Díaz Marulanda       6
# Nahuel Molina Lucero               1
# Nicolás Alejandro Tagliafico       3
# Richard Rios Montoya               2
# Rodrigo Javier De Paul             1
# Ángel Fabián Di María Hernández    7
# Name: id, dtype: int64

# %%
grouped_events = sb.competition_events(
    country="South America",
    division= "Copa America",
    season="2024",
    split=True
)
# Out:
# c:\Users\Federico Rábanos\AppData\Local\Programs\Python\Python310\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
grouped_events.keys()
# Out:
# dict_keys(['starting_xis', 'half_starts', 'passes', 'ball_receipts', 'carrys', 'pressures', 'shots', 'goal_keepers', 'clearances', 'blocks', 'dribbled_pasts', 'dribbles', 'duels', 'ball_recoverys', 'miscontrols', 'interceptions', 'foul_committeds', 'foul_wons', 'dispossesseds', 'tactical_shifts', 'injury_stoppages', 'offsides', 'player_offs', 'player_ons', 'shields', 'half_ends', '50/50s', 'referee_ball_drops', 'substitutions', 'bad_behaviours', 'errors', 'own_goal_fors', 'own_goal_againsts'])

# %%
grouped_events['tactical_shifts']
# Out:
#                                        id  index  period     timestamp  \
# 0    ed199fec-5864-432f-b605-cfd6cfbbd738    641       1  00:16:08.585
# 1    fee54c98-f934-4b72-ae46-de960fecd6a2   2388       2  00:21:26.106
# 2    5db6f894-bf95-49bd-b61e-a1f8ac5dfa0f   3346       3  00:06:47.798
# 3    f3b34036-e538-4ebd-867e-5ff102b466d4   3906       4  00:11:37.301
# 4    7715f1e6-9cd1-4484-aa5f-e8df9280032f   1520       2  00:00:09.565
# ..                                    ...    ...     ...           ...
# 119  8cb07a63-44ee-4029-9ce6-af1701566ec5   1628       2  00:00:00.000
# 120  e20937e4-5752-4e6f-9cad-eb47531bc9b0   2911       2  00:22:08.965
# 121  0977c964-f9d9-4808-bb27-7b592e4c303c   3177       2  00:31:23.937
# 122  0b964da2-71a1-41c3-ac09-bccdee37b3b0   3267       2  00:34:24.807
# 123  b69f2be6-c939-4cd4-b7a4-971c953610a7   3391       2  00:40:12.963
#
#      minute  second            type  possession possession_team  \
# ...

# %%
sb.events(match_id=3943077)
# Out:
# c:\Users\Federico Rábanos\AppData\Local\Programs\Python\Python310\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#      50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0      NaN                NaN                  NaN                     NaN
# 1      NaN                NaN                  NaN                     NaN
# 2      NaN                NaN                  NaN                     NaN
# 3      NaN                NaN                  NaN                     NaN
# 4      NaN                NaN                  NaN                     NaN
# ...    ...                ...                  ...                     ...
# 4103   NaN                NaN                  NaN                     NaN
# 4104   NaN                NaN                  NaN                     NaN
# 4105   NaN                NaN                  NaN                     NaN
# ...
