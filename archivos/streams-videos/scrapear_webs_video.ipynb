# %%
import requests
import json
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# %%
response = requests.get('https://www.mercadolibre.com.ar/ofertas#c_id=/home/promotions-recommendations&c_uid=afc81145-8afd-4d44-a846-ce5bf340bd2e')

# %%
response.text
# Out:
# '\n<!DOCTYPE html>\n<html lang="es-AR">\n<head><link rel="preconnect" href="https://www.google-analytics.com"/><link rel="preconnect" href="https://www.google.com"/><link rel="preconnect" href="https://data.mercadolibre.com"/><link rel="preconnect" href="https://http2.mlstatic.com"/><link rel="preconnect" href="https://stats.g.doubleclick.net"/><link rel="preconnect" href="https://analytics.mercadolibre.com.ar"/><link rel="preconnect" href="https://analytics.mercadolibre.com"/><link rel="preconnect" href="https://www.google.com.ar"/><script type=\'text/javascript\' nonce="srK4n3V3Nw1Fye+izgUnEA==">window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"NRBR-766f4fb616d3a2368ce","applicationID":"1032576013","agentToken":null,"applicationTime":862.662694,"transactionName":"YlZQYEVZC0QEV0BZV1scd0xHSgBEFl5HH39wZx0bWF4ARRFVRxwXWlVXRkNZFkUAR0Bf","queueTime":0,"ttGuid":"69fc2c85939390fa"}; (window.NREUM||(NREUM={})).init={aj
# ...

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="es-AR">
# ...

# %%
data = soup.select('div[class="promotion-item__container"]')

# %%
for x in data:
    print(x.text)

# %%
nombres = soup.find_all(class_='promotion-item__title')
precios = soup.find_all(class_='andes-money-amount__fraction')
descuentos = soup.find_all(class_='andes-money-amount__discount')

for x, y, z in zip(nombres, precios, descuentos):
    print(f'{x.text} // {y.text} // {z.text}')
# Out:
# Samsung Galaxy S23 Fe 256gb 8gb Ram Verde // 459.999 // 20% OFF
# Resma A4  Pack X10 Unidades Hojas Papel Blanco Hoja Resmas  // 579.999 // 14% OFF
# Zapatillas Blancas Hombre Mujer Urbana Anatomica Irak Comoda // 31.687 // 53% OFF
# Liliana VTF16P De pared/De piso - 16 " - Negro - 220V - Negro - 5 // 36.990 // 46% OFF
# Monitor Led Samsung 24'' Ips 75hz - Lf24t350fhlczb Color Negro // 16.256 // 21% OFF
# Smart Tv 32¨ Philips Android Hd 32phd6917/77 + Bluetooth // 34.810 // 25% OFF
# Taladro Atornillador Percutor + 2 Baterias Gp By Lusqtoff // 26.999 // 7% OFF
# Memoria Ram Fury Beast Ddr4 Gamer Color Negro 16gb 1 Kingston Kf432c16bb/16 // 49.999 // 33% OFF
# Samsung Galaxy A04 64gb Color Verde // 101.799 // 11% OFF
# Topper Zapatillas Hombre - T.350 Mesh Ngro // 129.657 // 16% OFF
# Ventilador 3 en 1 Winco W118 negro con 5 palas color  gris de  aluminio, 18" de diámetro 220 V // 128.999 // 40% OFF
# ...

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())

url = "https://www.mercadolibre.com.ar/ofertas#c_id=/home/promotions-recommendations&c_uid=86b23e1b-a12c-45d3-8bf9-06fbaa98dbe6"

driver.get(url)

#Procesos a ejecutar con el driver abierto.
cookie_banner = driver.find_element_by_class_name("cookie-consent-banner-opt-out__container")
if cookie_banner.is_displayed():
    cookie_banner.click()

for i in range(0,7):
    boton = driver.find_element_by_css_selector(".andes-pagination__button.andes-pagination__button--next")
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    nombres = soup.find_all(class_='promotion-item__title')
    precios = soup.find_all(class_='andes-money-amount__fraction')
    descuentos = soup.find_all(class_='andes-money-amount__discount')

    for x, y, z in zip(nombres, precios, descuentos):
        print(f'{x.text} // {y.text} // {z.text}')

    boton.click()

driver.quit()
# Out:
# Resma A4  Pack X10 Unidades Hojas Papel Blanco Hoja Resmas  // 31.687 // 14% OFF
# Zapatillas Blancas Hombre Mujer Urbana Anatomica Irak Comoda // 36.990 // 53% OFF
# Ventilador 3 en 1 Winco W118 negro con 5 palas color  gris de  aluminio, 18" de diámetro 220 V // 16.256 // 40% OFF
# Smart Tv Philips Fhd De 43  Con Google Tv // 34.810 // 31% OFF
# Memoria Ram Fury Beast Ddr4 Gamer Color Negro 16gb 1 Kingston Kf432c16bb/16 // 35.999 // 33% OFF
# Taladro Atornillador Percutor + 2 Baterias Gp By Lusqtoff // 59.999 // 7% OFF
# Samsung Galaxy S23 Fe 128gb 8gb Ram Crema  // 182.999 // 20% OFF
# Monitor Led Samsung 24'' Ips 75hz - Lf24t350fhlczb Color Negro // 267.505 // 21% OFF
# Topper Zapatillas Hombre - T.350 Mesh Ngro // 42.150 // 16% OFF
# Liliana VTF16P De pared/De piso - 16 " - Negro - 220V - Negro - 5 // 62.999 // 46% OFF
# Smart Tv 32¨ Philips Android Hd 32phd6917/77 + Bluetooth // 62.612 // 25% OFF
# Sommier Colchon 2 Plazas Elite Himalaya 1,90 X 1,40 Espuma // 67.499 // 42% OFF
# ...
