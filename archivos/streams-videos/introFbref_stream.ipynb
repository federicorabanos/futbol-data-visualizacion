# %%
import pandas as pd
from matplotlib.offsetbox import (OffsetImage,AnnotationBbox)
import matplotlib.pyplot as plt
from mplsoccer import FontManager, add_image
from PIL import Image

def path_logo():
    return {path a la imagen}}

URL3 = 'https://github.com/VanillaandCream/Catamaran-Tamil/blob/master/Fonts/Catamaran-Medium.ttf?raw=true'
catamaran2 = FontManager(URL3)
URL = 'https://github.com/google/fonts/blob/main/ofl/fjallaone/FjallaOne-Regular.ttf?raw=true'
robotto_regular = FontManager(URL)
URL2 = 'https://github.com/VanillaandCream/Catamaran-Tamil/blob/master/Fonts/Catamaran-ExtraBold.ttf?raw=true'
catamaran = FontManager(URL2)
URL4 = 'https://github.com/google/fonts/blob/main/ofl/bungeeinline/BungeeInline-Regular.ttf?raw=true'
titulo = FontManager(URL4)

# %%
df = pd.read_html('https://fbref.com/en/comps/21/Primera-Division-Stats#all_stats_squads_shooting')[5]

# %%
df
# Out:
#                     Unnamed: 0_level_0 Unnamed: 1_level_0 Playing Time         \
#                                  Squad               # Pl           MP Starts
# 0                       Argentinos Jun                  2           20     20
# 1                              Arsenal                  1           20     20
# 2                             Banfield                  1           20     20
# 3                     Barracas Central                  2           20     20
# 4                         Boca Juniors                  2           20     20
# 5                           CA Huracán                  2           20     20
# 6                             CA Unión                  2           19     19
# 7                           CC Córdoba                  2           20     20
# 8               Club Atlético Belgrano                  2           20     20
# 9                                Colón                  1           20     20
# ...

# %%
df.columns
# Out:
# MultiIndex([('Unnamed: 0_level_0',  'Squad'),
#             ('Unnamed: 1_level_0',   '# Pl'),
#             (      'Playing Time',     'MP'),
#             (      'Playing Time', 'Starts'),
#             (      'Playing Time',    'Min'),
#             (      'Playing Time',    '90s'),
#             (       'Performance',     'GA'),
#             (       'Performance',   'GA90'),
#             (       'Performance',   'SoTA'),
#             (       'Performance',  'Saves'),
#             (       'Performance',  'Save%'),
#             (       'Performance',      'W'),
#             (       'Performance',      'D'),
#             (       'Performance',      'L'),
#             (       'Performance',     'CS'),
#             (       'Performance',    'CS%'),
#             (     'Penalty Kicks',  'PKatt'),
#             (     'Penalty Kicks',    'PKA'),
#             (     'Penalty Kicks',   'PKsv'),
#             (     'Penalty Kicks',    'PKm'),
# ...

# %%
df.columns = df.columns.droplevel(0)

# %%
df_plot = df[['Squad', 'MP', 'Saves', 'Save%']]
df_plot
# Out:
#                                  Squad  MP  Saves  Save%  Save%
# 0                       Argentinos Jun  20     39   75.0    0.0
# 1                              Arsenal  20     79   78.2    0.0
# 2                             Banfield  20     52   68.4    0.0
# 3                     Barracas Central  20     63   72.7    0.0
# 4                         Boca Juniors  20     45   72.9   50.0
# 5                           CA Huracán  20     49   68.6   33.3
# 6                             CA Unión  19     53   71.6   33.3
# 7                           CC Córdoba  20     59   75.3   33.3
# 8               Club Atlético Belgrano  20     60   79.5   50.0
# 9                                Colón  20     63   78.8    0.0
# 10                      Defensa y Just  19     66   84.6    NaN
# 11                         Estudiantes  20     31   67.4    0.0
# 12                        Gimnasia ELP  20     53   68.8    0.0
# 13                          Godoy Cruz  20     42   73.7    0.0
# ...

# %%
df_plot['Saves / partido'] = df_plot['Saves'] / df_plot['MP']
# Out:
# <ipython-input-55-7f11d1dd8675>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Saves / partido'] = df_plot['Saves'] / df_plot['MP']

# %%
df_plot.Squad = df_plot.Squad.replace({
    'Tucumán': 'Atletico Tucuman',
    'Club Atlético Belgrano': 'Belgrano',
    'CA Huracán': 'Huracan',
    'CA Unión': 'Unión'
}).sort_values()

df_plot
# Out:
# c:\Users\Federico Rábanos\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#                                  Squad  MP  Saves  Save%  Save%  \
# 0                       Argentinos Jun  20     39   75.0    0.0
# 1                              Arsenal  20     79   78.2    0.0
# 2                             Banfield  20     52   68.4    0.0
# 3                     Barracas Central  20     63   72.7    0.0
# 4                         Boca Juniors  20     45   72.9   50.0
# 5                              Huracan  20     49   68.6   33.3
# 6                                Unión  19     53   71.6   33.3
# ...

# %%
#Seteo los parametros del scatter
x, promx = df_plot['Save%'].iloc[:,0], df_plot['Save%'].iloc[:,0].mean() 
y, promy = df_plot['Saves / partido'], df_plot['Saves / partido'].mean()

#Consideraciones generales
facecolor = '#292323'
color_plot = 'white'

#Figura, axis y el scatter
fig, ax = plt.subplots(figsize =(20, 12))
ax.scatter(x, y)

#Detalles esteticos
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_color(color_plot)
ax.spines['left'].set_color(color_plot)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(1.5)
ax.yaxis.set_tick_params(pad = 12,colors=color_plot,labelsize=12)
ax.xaxis.set_tick_params(pad = 12,colors=color_plot,labelsize=12)

fig.patch.set_facecolor(facecolor)
ax.set_facecolor(facecolor)
ax.grid(b=True, color =color_plot,linestyle ='-', linewidth = 0,alpha = 0.5)
ax.grid(which='minor', color =color_plot,linestyle ='-', linewidth = 1.5, alpha=1)

#Lineas de Promedio
ax.axvline(promx, color=color_plot)
ax.axhline(promy, color=color_plot)

#Nombres de labels y titulo
nombreAtr1 = 'Goles concedidos'
nombreAtr2 = 'Tiros al arco concedidos'

ax.set_xlabel(nombreAtr1, fontproperties=catamaran2.prop,fontsize=18,color=color_plot)
ax.set_ylabel(nombreAtr2, fontproperties=catamaran2.prop,fontsize=18,color=color_plot)
ax.set_title(nombreAtr1+' Vs '+nombreAtr2+''+' - Torneo Binance 2023', fontproperties=titulo.prop,
                     loc ='left', color=color_plot,fontsize = 25,fontweight="bold", pad=20)
# Out:
# Text(0.0, 1.0, 'Goles concedidos Vs Tiros al arco concedidos - Torneo Binance 2023')

# %%
import os
path = os.getcwd()
files = os.listdir('path/ejemplo')
files

# %%
#Seteo los parametros del scatter
x, promx = df_plot['Save%'].iloc[:,0], df_plot['Save%'].iloc[:,0].mean() 
y, promy = df_plot['Saves / partido'], df_plot['Saves / partido'].mean()

#Consideraciones generales
facecolor = '#292323'
color_plot = 'white'

#Figura, axis y el scatter
fig, ax = plt.subplots(figsize =(20, 12))
ax.scatter(x, y)

#Detalles esteticos
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_color(color_plot)
ax.spines['left'].set_color(color_plot)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(1.5)
ax.yaxis.set_tick_params(pad = 12,colors=color_plot,labelsize=12)
ax.xaxis.set_tick_params(pad = 12,colors=color_plot,labelsize=12)

fig.patch.set_facecolor(facecolor)
ax.set_facecolor(facecolor)
ax.grid(b=True, color =color_plot,linestyle ='-', linewidth = 0,alpha = 0.5)
ax.grid(which='minor', color =color_plot,linestyle ='-', linewidth = 1.5, alpha=1)

#Lineas de Promedio
ax.axvline(promx, color=color_plot)
ax.axhline(promy, color=color_plot)

#Nombres de labels y titulo
nombreAtr1 = '% de tiros atajados'
nombreAtr2 = 'Atajadas por partido'

ax.set_xlabel(nombreAtr1, fontproperties=catamaran2.prop,fontsize=18,color=color_plot)
ax.set_ylabel(nombreAtr2, fontproperties=catamaran2.prop,fontsize=18,color=color_plot)
ax.set_title(nombreAtr1+' Vs '+nombreAtr2+''+' - Torneo Binance 2023', fontproperties=titulo.prop,
                     loc ='left', color=color_plot,fontsize = 25,fontweight="bold", pad=20)

#Escudos
def getImage(path, zoom=0.17):
    return OffsetImage(plt.imread(path), zoom=zoom)

for x0, y0, file in zip(x, y,files):
    path = path.lower()
    ab = AnnotationBbox(getImage(f'pàth/ejemplo/{file}'), (x0, y0), frameon=False)
    ax.add_artist(ab)


ax_image = add_image(
    Image.open(path_logo()), fig, left=0.07, bottom=0.8774, width=0.053, height=0.053
)

plt.savefig(nombreAtr1+' Vs '+nombreAtr2+''+' - Torneo Binance 2023', dpi=300, bbox_inches='tight')
