# %%
import numpy as np
import matplotlib.pyplot as plt
from mplsoccer import VerticalPitch, Pitch
from matplotlib.colors import to_rgba
from statsbombpy import sb
import pandas as pd

# %%
partido = sb.events(match_id=3869685)
# Out:
# credentials were not supplied. open data access only

# %%
partido[['x', 'y']] = partido['location'].apply(pd.Series)
partido[['end_x', 'end_y']] = partido['pass_end_location'].apply(pd.Series)
partido['pasador'] = partido['player']
partido['receptor'] = partido['player'].shift(-1)
pases_partido = partido[(partido['type'] == 'Pass') & (partido['team'] == 'Argentina')]

completados = pases_partido[pases_partido['pass_outcome'].isna() == True]

# %%
completados.minute.describe()
# Out:
# count    560.000000
# mean      57.198214
# std       35.113132
# min        0.000000
# 25%       31.000000
# 50%       50.000000
# 75%       92.000000
# max      123.000000
# Name: minute, dtype: float64

# %%
firstSub = partido[(partido['type'] == 'Substitution') & (partido['team'] == 'Argentina')].minute.min()
completados_cambio = completados[completados['minute'] < firstSub]
average_locations = completados_cambio.groupby('player').agg({'x': ['mean'], 'y': ['mean', 'count']})

# %%
pass_between = completados_cambio.groupby(['pasador', 'receptor']).id.count().reset_index()
pass_between.rename({'id': 'pass_count'}, axis='columns',inplace=True)

# %%
average_locations.columns = average_locations.columns.droplevel(0)

# %%
average_locations['x'] = average_locations.iloc[:, 0]
average_locations['y'] = average_locations.iloc[:, 1]
average_locations = average_locations.drop(columns=['mean'])

# %%
pass_between = pass_between.merge(average_locations, left_on='pasador', right_index=True)
pass_between = pass_between.merge(average_locations, left_on='receptor', right_index=True, suffixes=['','_end'])
pass_between = pass_between[pass_between['pass_count'] > 1]

# %%
pass_between
# Out:
#                             pasador                         receptor  \
# 0               Alexis Mac Allister                   Enzo Fernandez
# 12          Cristian Gabriel Romero                   Enzo Fernandez
# 36                   Julián Álvarez                   Enzo Fernandez
# 44   Lionel Andrés Messi Cuccittini                   Enzo Fernandez
# 53             Nahuel Molina Lucero                   Enzo Fernandez
# 60     Nicolás Alejandro Tagliafico                   Enzo Fernandez
# 68          Nicolás Hernán Otamendi                   Enzo Fernandez
# 77           Rodrigo Javier De Paul                   Enzo Fernandez
# 84  Ángel Fabián Di María Hernández                   Enzo Fernandez
# 13          Cristian Gabriel Romero                   Julián Álvarez
# 45   Lionel Andrés Messi Cuccittini                   Julián Álvarez
# 54             Nahuel Molina Lucero                   Julián Álvarez
# 2               Alexis Mac Allister   Lionel Andrés Messi Cuccittini
# 30                   Enzo Fernandez   Lionel Andrés Messi Cuccittini
# 38                   Julián Álvarez   Lionel Andrés Messi Cuccittini
# 55             Nahuel Molina Lucero   Lionel Andrés Messi Cuccittini
# 80           Rodrigo Javier De Paul   Lionel Andrés Messi Cuccittini
# 88  Ángel Fabián Di María Hernández   Lionel Andrés Messi Cuccittini
# 3               Alexis Mac Allister     Nicolás Alejandro Tagliafico
# 32                   Enzo Fernandez     Nicolás Alejandro Tagliafico
# 69          Nicolás Hernán Otamendi     Nicolás Alejandro Tagliafico
# 90  Ángel Fabián Di María Hernández     Nicolás Alejandro Tagliafico
# 16          Cristian Gabriel Romero          Nicolás Hernán Otamendi
# 22         Damián Emiliano Martínez          Nicolás Hernán Otamendi
# 33                   Enzo Fernandez          Nicolás Hernán Otamendi
# 62     Nicolás Alejandro Tagliafico          Nicolás Hernán Otamendi
# 82           Rodrigo Javier De Paul          Nicolás Hernán Otamendi
# 91  Ángel Fabián Di María Hernández          Nicolás Hernán Otamendi
# 8               Alexis Mac Allister  Ángel Fabián Di María Hernández
# 18          Cristian Gabriel Romero  Ángel Fabián Di María Hernández
# 49   Lionel Andrés Messi Cuccittini  Ángel Fabián Di María Hernández
# 64     Nicolás Alejandro Tagliafico  Ángel Fabián Di María Hernández
# 73          Nicolás Hernán Otamendi  Ángel Fabián Di María Hernández
# 24                   Enzo Fernandez              Alexis Mac Allister
# 35                   Julián Álvarez              Alexis Mac Allister
# 42   Lionel Andrés Messi Cuccittini              Alexis Mac Allister
# 50             Nahuel Molina Lucero              Alexis Mac Allister
# 58     Nicolás Alejandro Tagliafico              Alexis Mac Allister
# 74           Rodrigo Javier De Paul              Alexis Mac Allister
# 83  Ángel Fabián Di María Hernández              Alexis Mac Allister
# 10          Cristian Gabriel Romero         Damián Emiliano Martínez
# 52             Nahuel Molina Lucero         Damián Emiliano Martínez
# 67          Nicolás Hernán Otamendi         Damián Emiliano Martínez
# 76           Rodrigo Javier De Paul         Damián Emiliano Martínez
# 15          Cristian Gabriel Romero             Nahuel Molina Lucero
# 21         Damián Emiliano Martínez             Nahuel Molina Lucero
# 31                   Enzo Fernandez             Nahuel Molina Lucero
# 46   Lionel Andrés Messi Cuccittini             Nahuel Molina Lucero
# 81           Rodrigo Javier De Paul             Nahuel Molina Lucero
# 89  Ángel Fabián Di María Hernández             Nahuel Molina Lucero
# 17          Cristian Gabriel Romero           Rodrigo Javier De Paul
# 34                   Enzo Fernandez           Rodrigo Javier De Paul
# 40                   Julián Álvarez           Rodrigo Javier De Paul
# 48   Lionel Andrés Messi Cuccittini           Rodrigo Javier De Paul
# 57             Nahuel Molina Lucero           Rodrigo Javier De Paul
# 19         Damián Emiliano Martínez          Cristian Gabriel Romero
# 26                   Enzo Fernandez          Cristian Gabriel Romero
# 66          Nicolás Hernán Otamendi          Cristian Gabriel Romero
# 75           Rodrigo Javier De Paul          Cristian Gabriel Romero
#
#     pass_count  count          x          y  count_end      x_end      y_end  \
# 0            6     24  68.737500  23.845833         40  56.135000  36.532500
# 12           7     39  33.905128  53.346154         40  56.135000  36.532500
# 36           3     13  76.346154  37.538462         40  56.135000  36.532500
# 44           2     27  71.588889  51.096296         40  56.135000  36.532500
# 53           2     28  59.414286  72.085714         40  56.135000  36.532500
# 60           4     28  58.567857   7.335714         40  56.135000  36.532500
# 68          10     44  38.279545  23.350000         40  56.135000  36.532500
# 77           3     37  59.159459  59.248649         40  56.135000  36.532500
# 84           3     25  79.884000  11.448000         40  56.135000  36.532500
# 13           2     39  33.905128  53.346154         13  76.346154  37.538462
# 45           4     27  71.588889  51.096296         13  76.346154  37.538462
# 54           3     28  59.414286  72.085714         13  76.346154  37.538462
# 2            4     24  68.737500  23.845833         27  71.588889  51.096296
# 30           6     40  56.135000  36.532500         27  71.588889  51.096296
# 38           2     13  76.346154  37.538462         27  71.588889  51.096296
# 55           4     28  59.414286  72.085714         27  71.588889  51.096296
# 80           7     37  59.159459  59.248649         27  71.588889  51.096296
# 88           3     25  79.884000  11.448000         27  71.588889  51.096296
# 3            4     24  68.737500  23.845833         28  58.567857   7.335714
# 32           4     40  56.135000  36.532500         28  58.567857   7.335714
# 69           9     44  38.279545  23.350000         28  58.567857   7.335714
# 90           5     25  79.884000  11.448000         28  58.567857   7.335714
# 16           9     39  33.905128  53.346154         44  38.279545  23.350000
# 22           4     12  12.641667  43.966667         44  38.279545  23.350000
# 33           7     40  56.135000  36.532500         44  38.279545  23.350000
# 62           7     28  58.567857   7.335714         44  38.279545  23.350000
# 82           7     37  59.159459  59.248649         44  38.279545  23.350000
# 91           3     25  79.884000  11.448000         44  38.279545  23.350000
# 8            5     24  68.737500  23.845833         25  79.884000  11.448000
# 18           2     39  33.905128  53.346154         25  79.884000  11.448000
# 49           5     27  71.588889  51.096296         25  79.884000  11.448000
# 64           8     28  58.567857   7.335714         25  79.884000  11.448000
# 73           4     44  38.279545  23.350000         25  79.884000  11.448000
# 24           2     40  56.135000  36.532500         24  68.737500  23.845833
# 35           3     13  76.346154  37.538462         24  68.737500  23.845833
# 42           3     27  71.588889  51.096296         24  68.737500  23.845833
# 50           2     28  59.414286  72.085714         24  68.737500  23.845833
# 58           6     28  58.567857   7.335714         24  68.737500  23.845833
# 74           3     37  59.159459  59.248649         24  68.737500  23.845833
# 83           2     25  79.884000  11.448000         24  68.737500  23.845833
# 10           3     39  33.905128  53.346154         12  12.641667  43.966667
# 52           2     28  59.414286  72.085714         12  12.641667  43.966667
# 67           5     44  38.279545  23.350000         12  12.641667  43.966667
# 76           2     37  59.159459  59.248649         12  12.641667  43.966667
# 15           5     39  33.905128  53.346154         28  59.414286  72.085714
# 21           2     12  12.641667  43.966667         28  59.414286  72.085714
# 31           5     40  56.135000  36.532500         28  59.414286  72.085714
# 46           5     27  71.588889  51.096296         28  59.414286  72.085714
# 81           5     37  59.159459  59.248649         28  59.414286  72.085714
# 89           2     25  79.884000  11.448000         28  59.414286  72.085714
# 17           8     39  33.905128  53.346154         37  59.159459  59.248649
# 34           6     40  56.135000  36.532500         37  59.159459  59.248649
# 40           2     13  76.346154  37.538462         37  59.159459  59.248649
# 48           6     27  71.588889  51.096296         37  59.159459  59.248649
# 57          13     28  59.414286  72.085714         37  59.159459  59.248649
# 19           4     12  12.641667  43.966667         39  33.905128  53.346154
# 26           6     40  56.135000  36.532500         39  33.905128  53.346154
# 66          12     44  38.279545  23.350000         39  33.905128  53.346154
# 75           7     37  59.159459  59.248649         39  33.905128  53.346154
#
#     width
# 0     6.0
# 12    7.0
# 36    3.0
# 44    2.0
# 53    2.0
# 60    4.0
# 68   10.0
# 77    3.0
# 84    3.0
# 13    2.0
# 45    4.0
# 54    3.0
# 2     4.0
# 30    6.0
# 38    2.0
# 55    4.0
# 80    7.0
# 88    3.0
# 3     4.0
# 32    4.0
# 69    9.0
# 90    5.0
# 16    9.0
# 22    4.0
# 33    7.0
# 62    7.0
# 82    7.0
# 91    3.0
# 8     5.0
# 18    2.0
# 49    5.0
# 64    8.0
# 73    4.0
# 24    2.0
# 35    3.0
# 42    3.0
# 50    2.0
# 58    6.0
# 74    3.0
# 83    2.0
# 10    3.0
# 52    2.0
# 67    5.0
# 76    2.0
# 15    5.0
# 21    2.0
# 31    5.0
# 46    5.0
# 81    5.0
# 89    2.0
# 17    8.0
# 34    6.0
# 40    2.0
# 48    6.0
# 57   13.0
# 19    4.0
# 26    6.0
# 66   12.0
# 75    7.0

# %%
MAX_LINE_WIDTH = 13
pass_between['width'] = (pass_between.pass_count / pass_between.pass_count.max() * MAX_LINE_WIDTH)

MIN_TRANSPARENCY = 0.000001
color = np.array(to_rgba('yellow'))
color = np.tile(color, (len(pass_between), 1))
c_transparency = pass_between.pass_count / pass_between.pass_count.max()
c_transparency = (c_transparency * (1 - MIN_TRANSPARENCY)) + MIN_TRANSPARENCY
color[:, 3] = c_transparency

MAX_MARKER_SIZE=800
average_locations['marker_size'] = (average_locations['count'] / average_locations['count'].max() * MAX_MARKER_SIZE)

# %%
def generar_mapa_pases(pases_comp, minuto_inicial, minuto_final, ax):
    completados = pases_comp[(pases_comp['minute'] >= minuto_inicial) & (pases_comp['minute'] < minuto_final)]
    average_locations = completados.groupby('player').agg({'x': ['mean'], 'y': ['mean', 'count']})
    pass_between = completados_cambio.groupby(['pasador', 'receptor']).id.count().reset_index()
    pass_between.rename({'id': 'pass_count'}, axis='columns',inplace=True)
    average_locations.columns = average_locations.columns.droplevel(0)
    average_locations['x'] = average_locations.iloc[:, 0]
    average_locations['y'] = average_locations.iloc[:, 1]
    average_locations = average_locations.drop(columns=['mean'])
    pass_between = pass_between.merge(average_locations, left_on='pasador', right_index=True)
    pass_between = pass_between.merge(average_locations, left_on='receptor', right_index=True, suffixes=['','_end'])
    pass_between = pass_between[pass_between['pass_count'] > 1]
    MAX_LINE_WIDTH = 13
    pass_between['width'] = (pass_between.pass_count / pass_between.pass_count.max() * MAX_LINE_WIDTH)

    MIN_TRANSPARENCY = 0.000001
    color = np.array(to_rgba('yellow'))
    color = np.tile(color, (len(pass_between), 1))
    c_transparency = pass_between.pass_count / pass_between.pass_count.max()
    c_transparency = (c_transparency * (1 - MIN_TRANSPARENCY)) + MIN_TRANSPARENCY
    color[:, 3] = c_transparency

    MAX_MARKER_SIZE=800
    average_locations['marker_size'] = (average_locations['count'] / average_locations['count'].max() * MAX_MARKER_SIZE)
    
    pitch = VerticalPitch(pitch_type='statsbomb', pitch_color='#292323', line_color='#c7d5cc', goal_type='box', goal_alpha=.8)
    pitch.draw(constrained_layout=False, tight_layout=True,ax=ax)

    arrows = pitch.arrows(pass_between.x, pass_between.y, pass_between.x_end, pass_between.y_end, ax=ax, color=color, zorder=.99)

    nodes = pitch.scatter(average_locations.x, average_locations.y, ax=ax, color='white', ec='black', s=average_locations['marker_size'])
    
    TITLE_TEXT = f'Min {minuto_inicial}-{minuto_final}'
    ax.text(40, 105, TITLE_TEXT, color='#c7d5cc', va='center', ha='center', fontsize=20)

# %%
partido[['x', 'y']] = partido['location'].apply(pd.Series)
partido[['end_x', 'end_y']] = partido['pass_end_location'].apply(pd.Series)
partido['pasador'] = partido['player']
partido['receptor'] = partido['player'].shift(-1)
pases_partido = partido[(partido['type'] == 'Pass') & (partido['team'] == 'Argentina')]

completados_tot = pases_partido[pases_partido['pass_outcome'].isna() == True]

# %%
fig = plt.figure(figsize=(20,15),constrained_layout=True)
gs = fig.add_gridspec(nrows=6,ncols=6)
fig.set_facecolor('#292323')

ax1 = fig.add_subplot(gs[0:3,0:2])
generar_mapa_pases(completados_tot, 0, 25, ax1)

ax2 = fig.add_subplot(gs[0:3,2:4])
generar_mapa_pases(completados_tot, 25, 45, ax2)


ax3 = fig.add_subplot(gs[0:3,4:])
generar_mapa_pases(completados_tot, 45, 70, ax3)


ax4 = fig.add_subplot(gs[3:,0:2])
generar_mapa_pases(completados_tot, 70, 90, ax4)


ax5 = fig.add_subplot(gs[3:,2:4])
generar_mapa_pases(completados_tot, 90, 105, ax5)


ax6 = fig.add_subplot(gs[3:,4:])
generar_mapa_pases(completados_tot, 105, 120, ax6)
