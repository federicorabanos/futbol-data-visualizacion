# %%
import LanusStats as ls  
fbref = ls.Fbref()

# %%
ls.get_available_pages()
# Out:
# dict_keys(['Fbref', 'Sofascore', '365Scores', 'Fotmob'])

# %%
ls.get_available_leagues('Fbref')
# Out:
# ['Copa de la Liga',
#  'Primera Division Argentina',
#  'Primera Division Uruguay',
#  'Brasileirao',
#  'Brasileirao B',
#  'Primera Division Colombia',
#  'Primera Division Chile',
#  'Primera Division Peru',
#  'Primera Division Venezuela',
#  'Primera Division Ecuador',
#  'Primera Division Bolivia',
#  'Primera Division Paraguay',
#  'Brasileirao F',
#  'MLS',
#  'USL Championship',
#  'Premier League',
#  'La Liga',
#  'Ligue 1',
#  'Bundesliga',
#  'Serie A',
#  'Big 5 European Leagues']

# %%
ls.get_available_season_for_leagues('Fbref', 'Copa de la Liga')
# Out:
# {'id': 905,
#  'slug': 'Copa-de-la-Liga-Profesional',
#  'seasons': {'2020', '2021', '2022', '2023', '2024'}}

# %%
fbref.possible_stats
# Out:
# ['stats',
#  'keepers',
#  'keepersadv',
#  'shooting',
#  'passing',
#  'passing_types',
#  'gca',
#  'defense',
#  'possession',
#  'playingtime',
#  'misc']

# %%
fbref.get_teams_season_stats('gca', 'Copa de la Liga', '2024', change_columns_names=True, add_page_name=True, stats_vs=True)
# Out:
# Starting to scrape teams data from Fbref...
#                      gca_Squad  gca_# Pl  gca_90s  gca_SCA_SCA  gca_SCA_SCA90  \
# 0               vs Arg Juniors        26     14.0          305          21.79
# 1              vs Atlé Tucumán        24     14.0          259          18.50
# 2                  vs Banfield        27     14.0          318          22.71
# 3          vs Barracas Central        24     14.0          385          27.50
# 4                  vs Belgrano        33     14.0          313          22.36
# 5              vs Boca Juniors        29     14.0          234          16.71
# 6          vs Cen. Córdoba–SdE        31     14.0          338          24.14
# 7            vs Defensa y Just        30     14.0          316          22.57
# 8         vs Deportivo Riestra        30     14.0          330          23.57
# 9               vs Estudiantes        29     14.0          271          19.36
# ...

# %%
dfs =fbref.get_vs_and_teams_season_stats('gca', 'Copa de la Liga', '2024')
dfs[0]
# Out:
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
#                       Squad  # Pl   90s  SCA  SCA90  PassLive  PassDead  TO  \
# 0               Arg Juniors    26  14.0  314  22.43       232        25  18
# 1              Atlé Tucumán    24  14.0  331  23.64       215        38  22
# 2                  Banfield    27  14.0  260  18.57       157        45  15
# 3          Barracas Central    24  14.0  264  18.86       171        30  25
# 4                  Belgrano    33  14.0  264  18.86       172        30  20
# 5              Boca Juniors    29  14.0  275  19.64       189        28  19
# 6          Cen. Córdoba–SdE    31  14.0  207  14.79       133        23  22
# 7            Defensa y Just    30  14.0  277  19.79       189        29  25
# 8         Deportivo Riestra    30  14.0  178  12.71       110        26  13
# 9               Estudiantes    29  14.0  367  26.21       268        27  27
# ...

# %%
dfs[1]
# Out:
#                          Squad  # Pl   90s  SCA  SCA90  PassLive  PassDead  \
# 0               vs Arg Juniors    26  14.0  305  21.79       191        42
# 1              vs Atlé Tucumán    24  14.0  259  18.50       150        37
# 2                  vs Banfield    27  14.0  318  22.71       231        26
# 3          vs Barracas Central    24  14.0  385  27.50       281        45
# 4                  vs Belgrano    33  14.0  313  22.36       221        33
# 5              vs Boca Juniors    29  14.0  234  16.71       152        25
# 6          vs Cen. Córdoba–SdE    31  14.0  338  24.14       225        38
# 7            vs Defensa y Just    30  14.0  316  22.57       221        39
# 8         vs Deportivo Riestra    30  14.0  330  23.57       250        23
# 9               vs Estudiantes    29  14.0  271  19.36       169        29
# 10              vs Gimnasia–LP    26  14.0  338  24.14       229        40
# ...

# %%
df_total = fbref.get_all_teams_season_stats('Copa de la Liga', '2024', change_columns_names=True)
# Out:
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...

# %%
fbref.get_player_season_stats('gca', 'Copa de la Liga', '2024', add_page_name=True)
# Out:
# Starting to scrape player data from Fbref...
#                Player gca_Nation gca_Pos                gca_Squad  \
# 0       Matías Abaldo     uy URU   MF,FW              Gimnasia–LP
# 1    Luciano Abecasis     ar ARG   MF,DF  Independiente Rivadavia
# 2         Ramón Ábila     ar ARG      FW         Barracas Central
# 3       Jonás Acevedo     ar ARG   MF,FW                Instituto
# 4    Guillermo Acosta     ar ARG      MF             Atlé Tucumán
# ..                ...        ...     ...                      ...
# 762    Felipe Zenobio     ar ARG      GK                    Tigre
# 763       Kevin Zenon     ar ARG      MF             Boca Juniors
# 764       Juan Zozaya     ar ARG      GK              Estudiantes
# 765    Bruno Zuculini     ar ARG      MF              Racing Club
# 766    Fernando Zuqui     ar ARG      MF              Estudiantes
#
#             gca_Comp gca_Age gca_Born gca_90s gca_SCA gca_SCA90  ... gca_Fld  \
# ...

# %%
fbref.get_all_player_season_stats('Copa de la Liga', '2024')

# %%
fbref.get_player_percentiles('https://fbref.com/es/jugadores/21512407/Kieran-Trippier')
# Out:
#                                       Estadísticas Por 90  Percentil
# 0                           Goles sin penalización   0.03       43.0
# 1   npxG: Goles esperados (xG) sin contar penaltis   0.03       29.0
# 2                                Total de disparos   0.37       22.0
# 3                                      Asistencias   0.35       99.0
# 4                         xAG: Exp. Assisted Goals   0.28       98.0
# 5                                       npxG + xAG   0.31       95.0
# 6               Acciones para la creación de tiros   3.83       97.0
# 7                                              NaN    NaN        NaN
# 8                                 Pases intentados  82.71       98.0
# 9                               % de pase completo  75.9%       43.0
# 10                               Pases progresivos   6.74       96.0
# 11                            Acarreos progresivos   1.61       31.0
# 12                                  Tomas exitosas   0.55       34.0
# ...

# %%
ls.visualizations.fbref_plot_player_percentiles('https://fbref.com/es/jugadores/21512407/Kieran-Trippier', name_extra = '- Newcastle', credit_extra='Hecho en Video', chart_stats = ['Ataque', 'Pases', 'Defensa'])
# Out:
# Gettings player percentiles...
# Starting to plot...

# %%
fbref.get_player_similarities('https://fbref.com/es/jugadores/d1c92690/Guillermo-Vizcarra')
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                Fecha                Día               Comp
# 0         2024-04-28                Dom   Primera División
# 1         2024-04-20                Sáb   Primera División
# 2         2024-04-17                Mié   Primera División
# 3         2024-04-14                Dom   Primera División
# 4         2024-04-11                Jue   Primera División
#
#           Unnamed: 3_level_0 Unnamed: 4_level_0 Unnamed: 5_level_0  \
#                        Ronda              Sedes          Resultado
# 0     Apertura — Semi-finals              Local      D 1 (8)–2 (9)
# 1     Apertura — Semi-finals          Visitante              V 1–0
# 2  Apertura — Quarter-finals              Local              V 2–1
# 3  Apertura — Quarter-finals          Visitante              V 2–0
# 4              Primera etapa          Visitante              V 3–2
#
# ...

# %%
fbref.get_match_shots('https://fbref.com/es/partidos/c2224006/The-Strongest-FC-Universitario-Abril-28-2024-Bolivian-Primera-Division')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\Federico Rábanos\AppData\Local\Programs\Python\Python310\lib\site-packages\LanusStats\fbref.py:38, in Fbref.match_info_exception(self, path)
#      37 try:
# ---> 38     data[17]
#      39 except IndexError:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# MatchDoesntHaveInfo                       Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 fbref.get_match_shots('https://fbref.com/es/partidos/c2224006/The-Strongest-FC-Universitario-Abril-28-2024-Bolivian-Primera-Division')
#
# File c:\Users\Federico Rábanos\AppData\Local\Programs\Python\Python310\lib\site-packages\LanusStats\fbref.py:325, in Fbref.get_match_shots(self, path)
#     324 def get_match_shots(self, path):
# --> 325     self.match_info_exception(path)
# ...

# %%
fbref.get_general_match_team_stats('https://fbref.com/es/partidos/e92d40be/Newcastle-United-Sheffield-United-Abril-27-2024-Premier-League')[0]
# Out:
#       Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Jugador               núm.               País
# 0         Alexander Isak               14.0             se SWE
# 1         Anthony Gordon               10.0            eng ENG
# 2           Matt Ritchie               11.0            sct SCO
# 3           Jacob Murphy               23.0            eng ENG
# 4          Harvey Barnes               15.0            eng ENG
# 5        Elliot Anderson               32.0            sct SCO
# 6          Callum Wilson                9.0            eng ENG
# 7        Bruno Guimarães               39.0             br BRA
# 8         Sean Longstaff               36.0            eng ENG
# 9             Lewis Hall               20.0            eng ENG
# 10           Alex Murphy               54.0             ie IRL
# 11              Dan Burn               33.0            eng ENG
# 12          Fabian Schär                5.0             ch SUI
# ...

# %%
fbref.get_tournament_table('https://fbref.com/es/comps/12/Estadisticas-de-La-Liga')
# Out:
#     RL           Equipo  PJ  PG  PE  PP  GF  GC  DG  Pts  Pts/PJ    xG   xGA  \
# 0    1      Real Madrid  33  26   6   1  71  22  49   84    2.55  60.5  29.7
# 1    2        Barcelona  33  22   7   4  68  39  29   73    2.21  68.7  35.5
# 2    3           Girona  33  22   5   6  69  40  29   71    2.15  58.5  45.3
# 3    4  Atlético Madrid  33  20   4   9  62  39  23   64    1.94  55.4  35.7
# 4    5    Athletic Club  33  16  10   7  53  33  20   58    1.76  48.0  33.1
# 5    6    Real Sociedad  33  13  12   8  46  35  11   51    1.55  41.3  33.9
# 6    7            Betis  33  12  13   8  41  39   2   49    1.48  38.3  44.6
# 7    8         Valencia  33  13   8  12  37  38  -1   47    1.42  34.9  40.8
# 8    9       Villarreal  33  12   9  12  54  55  -1   45    1.36  47.9  49.4
# 9   10           Getafe  33  10  13  10  41  45  -4   43    1.30  39.0  47.8
# 10  11          Osasuna  33  11   6  16  37  49 -12   39    1.18  35.6  43.2
# ...
